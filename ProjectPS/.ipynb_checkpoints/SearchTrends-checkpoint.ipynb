# %%
# Import modules
from pytrends.request import TrendReq
import math
import os
import random
# Watch out for assert_frame_equal, independent imported
import pandas_datareader as web
from pandas.util.testing import assert_frame_equal
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
from datetime import date, datetime

# %%
def get_stock_hist(ticker, datasource, start, end=date.today()):
    df = web.DataReader(ticker, data_source=datasource, start=start, end=end)
    return df

close_list = []

stocks = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB']
for stock in stocks:
    df = get_stock_hist(stock, 'yahoo', '2015-07-05')['Close']
    df_week_close = df.reindex(pd.date_range( start=df.index.min( ),
                           end=df.index.max( ),
                           freq='W-MON' ) )  # weekly, Wednesdays
    close = list(df_week_close)
    close_list.append(close)

print(close_list)
# Out:
# [[126.0, 125.66000366210938, 132.07000732421875, 122.7699966430664, 118.44000244140625, 119.72000122070312, 117.16000366210938, 103.12000274658203, 112.76000213623047, nan, 115.30999755859375, 115.20999908447266, 112.44000244140625, 110.77999877929688, 111.5999984741211, 111.7300033569336, 115.27999877929688, 121.18000030517578, 120.56999969482422, 114.18000030517578, 117.75, 118.30000305175781, 118.27999877929688, 112.4800033569336, 107.33000183105469, 106.81999969482422, 105.3499984741211, 98.52999877929688, nan, 99.44000244140625, 96.43000030517578, 95.01000213623047, nan, 96.87999725341797, 96.69000244140625, 101.87000274658203, 102.5199966430664, 105.91000366210938, 105.19000244140625, 111.12000274658203, 109.0199966430664, 107.4800033569336, 105.08000183105469, 93.63999938964844, 92.79000091552734, 93.87999725341797, 96.43000030517578, nan, 98.62999725341797, 97.33999633789062, 95.0999984741211, 92.04000091552734, nan, 96.9800033569336, 99.83000183105469, 97.33999633789062, 106.05000305175781, 108.37000274658203, 109.4800033569336, 108.51000213623047, 106.81999969482422, nan, 105.44000244140625, 113.58000183105469, 112.87999725341797, 112.5199966430664, 116.05000305175781, 117.55000305175781, 117.6500015258789, 113.54000091552734, 110.41000366210938, 105.70999908447266, 111.7300033569336, 111.56999969482422, 109.11000061035156, 113.30000305175781, 116.63999938964844, nan, nan, 118.98999786376953, nan, 120.08000183105469, 121.62999725341797, 130.2899932861328, 133.2899932861328, nan, 136.92999267578125, 139.33999633789062, 139.1999969482422, 141.4600067138672, 140.8800048828125, 143.6999969482422, 143.1699981689453, 141.8300018310547, 143.63999938964844, 146.5800018310547, 153.00999450683594, 155.6999969482422, 153.99000549316406, nan, 153.92999267578125, 145.4199981689453, 146.33999633789062, 145.82000732421875, 143.5, 145.05999755859375, 149.55999755859375, 152.08999633789062, 148.72999572753906, 158.80999755859375, 159.85000610351562, 157.2100067138672, 161.47000122070312, nan, 161.5, 158.6699981689453, 150.5500030517578, 153.80999755859375, 155.83999633789062, 159.8800048828125, 156.1699981689453, 166.72000122070312, 174.25, 173.97000122070312, 169.97999572753906, 174.08999633789062, 169.8000030517578, 172.6699981689453, 176.4199981689453, nan, nan, 174.35000610351562, nan, 177.0, 167.9600067138672, 156.49000549316406, 162.7100067138672, nan, 178.97000122070312, 176.82000732421875, 181.72000122070312, 175.3000030517578, 172.77000427246094, 166.67999267578125, 170.0500030517578, 175.82000732421875, 165.24000549316406, 165.25999450683594, 185.16000366210938, 188.14999389648438, 187.6300048828125, nan, 191.8300018310547, 191.22999572753906, 188.74000549316406, 182.1699981689453, 187.17999267578125, 190.5800018310547, 190.91000366210938, 191.61000061035156, 189.91000366210938, 209.07000732421875, 208.8699951171875, 215.4600067138672, 217.94000244140625, nan, 218.3300018310547, 217.8800048828125, 220.7899932861328, 227.25999450683594, 223.77000427246094, 217.36000061035156, 220.64999389648438, 212.24000549316406, 201.58999633789062, 194.1699981689453, 185.86000061035156, 174.6199951171875, 184.82000732421875, 169.60000610351562, 163.94000244140625, 146.8300018310547, 157.74000549316406, 147.92999267578125, 150.0, nan, 156.3000030517578, 171.25, 169.42999267578125, nan, 174.22999572753906, 175.85000610351562, 178.89999389648438, 188.02000427246094, 188.74000549316406, 191.24000549316406, 200.10000610351562, 199.22999572753906, 204.52999877929688, 204.61000061035156, 208.47999572753906, 185.72000122070312, 183.08999633789062, nan, 173.3000030517578, 192.5800018310547, 193.88999938964844, 198.5800018310547, 201.5500030517578, 200.02000427246094, 205.2100067138672, 207.22000122070312, 209.67999267578125, 193.33999633789062, 200.47999572753906, 210.35000610351562, 206.49000549316406, nan, 214.1699981689453, 219.89999389648438, 218.72000122070312, 223.97000122070312, 227.05999755859375, 235.8699951171875, 240.50999450683594, 249 ...

# %%
pytrends = TrendReq()

kw_list = ["apple", "google", "microsoft", "amazon", "facebook"]
pytrend.build_payload(kw_list)

df_trend = pytrend.interest_over_time()
df_trend
# Out:
#             apple  google  microsoft  amazon  facebook isPartial
# date
# 2015-07-05      4      46          2       9        99     False
# 2015-07-12      4      46          2      10        99     False
# 2015-07-19      4      47          2       9        99     False
# 2015-07-26      3      47          2       9       100     False
# 2015-08-02      3      48          2       9        99     False
# ...           ...     ...        ...     ...       ...       ...
# 2020-05-31      4      32          2      13        30     False
# 2020-06-07      4      31          2      13        30     False
# 2020-06-14      4      30          2      13        29     False
# 2020-06-21      4      30          2      13        31     False
# 2020-06-28      4      30          2      13        30      True
#
# [261 rows x 6 columns]

# %%
import scipy

trend_list = [list(df_trend['apple']), list(df_trend['google']), list(df_trend['microsoft']), 
              list(df_trend['amazon']), list(df_trend['facebook'])]

nclose, napple = [], []

for n in range(len(close_list)):
    for i in range(len(close_list[n])):
        if not math.isnan(close[i]):
            nclose.append(close[i])
            napple.append(apple[i])
            correlation, p_value = scipy.stats.pearsonr(nclose, napple)
            print(correlation)
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-ff7444fd957a> in <module>
#      12             nclose.append(close[i])
#      13             napple.append(apple[i])
# ---> 14             correlation, p_value = scipy.stats.pearsonr(nclose, napple)
#      15             print(correlation)
#      16
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3499
#    3500     if n < 2:
# -> 3501         raise ValueError('x and y must have length at least 2.')
#    3502
#    3503     x = np.asarray(x)
#
# ValueError: x and y must have length at least 2.

# %%
# Out:
# 0.19102623851138997

# %%
plt.plot(nclose)
