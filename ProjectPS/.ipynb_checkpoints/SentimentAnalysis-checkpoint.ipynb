# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Another AT&T Streaming Service May Be Doomed
# Jul-05-20 12:35PM
# NASDAQ vs The DOW
# 12:34PM
# Big Tech CEOs Are Finally Ready to Talk to Congress. Heres How Theyve Handled Antirust Disclosures in the Past.
# 12:33PM
# ViacomCBS Decides to License Content to Rival Peacock: 3 Takeaways
# 11:29AM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'Jul-05-20',
#   '12:35PM',
#   'Another AT&T Streaming Service May Be Doomed'],
#  ['AMZN', 'Jul-05-20', '12:34PM', 'NASDAQ vs The DOW'],
#  ['AMZN',
#   'Jul-05-20',
#   '12:33PM',
#   'Big Tech CEOs Are Finally Ready to Talk to Congress. Heres How Theyve Handled Antirust Disclosures in the Past.'],
#  ['AMZN',
#   'Jul-05-20',
#   '11:29AM',
#   'ViacomCBS Decides to License Content to Rival Peacock: 3 Takeaways'],
#  ['AMZN',
#   'Jul-05-20',
#   '11:11AM',
#   '3 Top Stocks to Recession-Proof Your Portfolio'],
#  ['AMZN',
#   'Jul-05-20',
#   '10:00AM',
#   'Investors May Be Missing Out on a Once-in-a-Generation Opportunity. Again.'],
#  ['AMZN', 'Jul-05-20', '09:30AM', "Here's My Top Stock to Buy in July"],
#  ['AMZN',
#   'Jul-05-20',
#   '08:30AM',
#   'Shopify Stock Is More Expensive Than Amazon Ever Was'],
#  ['AMZN',
#   'Jul-05-20',
#   '08:11AM',
#   'Why Investors Should Steer Clear of (Most) Robinhood Stocks'],
#  ['AMZN',
#   'Jul-05-20',
#   '07:34AM',
#   "3 Stocks to Buy in the Market That Could Mint the World's First Trillionaire"],
#  ['AMZN',
#   'Jul-05-20',
#   '07:21AM',
#   '10 Things to Do When the Stock Market Crashes'],
#  ['AMZN',
#   'Jul-05-20',
#   '06:56AM',
#   "Warren Buffett's 3 Biggest Winners in the First Half of 2020: Are They Still Buys Now?"],
#  ['AMZN', 'Jul-04-20', '09:15AM', 'Why Datadog Stock Surged 22% in June'],
#  ['AMZN',
#   'Jul-04-20',
#   '07:30AM',
#   'There Are Now 4 Trillion-Dollar Stocks. Why There Might Not Be a Fifth Anytime Soon.'],
#  ['AMZN',
#   'Jul-04-20',
#   '07:20AM',
#   'Why ESG Stocks Are Perfect for Retirement Portfolios'],
#  ['AMZN',
#   'Jul-04-20',
#   '05:51AM',
#   '5 Top Stocks to Secure Your Financial Independence'],
#  ['AMZN', 'Jul-03-20', '03:21PM', '2 Hot Stocks to Buy in July'],
#  ['AMZN',
#   'Jul-03-20',
#   '08:13AM',
#   "Don't Expect Explosive Growth From the Amazon of Today"],
#  ['AMZN',
#   'Jul-03-20',
#   '08:08AM',
#   '5 Cloud Stocks Set to Rally in the Second Half of 2020'],
#  ['AMZN',
#   'Jul-03-20',
#   '08:00AM',
#   'Casinos, Like Airlines, Are Best Avoided for Now'],
#  ['AMZN',
#   'Jul-03-20',
#   '07:00AM',
#   'Balkanization Is Bad for Facebooks Business'],
#  ['AMZN',
#   'Jul-03-20',
#   '06:49AM',
#   'Zooms Newest Challenger: Budding Internet Tycoon Mukesh Ambani'],
#  ['AMZN',
#   'Jul-03-20',
#   '05:45AM',
#   "Tesla's Overexcited Fans Should Cool Down a Little"],
#  ['AMZN',
#   'Jul-03-20',
#   '05:05AM',
#   'Display Maker Royole Said to Mull China IPO as U.S. Plans Stall'],
#  ['AMZN',
#   'Jul-03-20',
#   '02:07AM',
#   'GLOBAL MARKETS-Asian shares hit 4-month high as U.S., China recoveries gather pace'],
#  ['AMZN', 'Jul-03-20', '12:01AM', 'Retail tech draws lockdown dollars'],
#  ['AMZN',
#   'Jul-02-20',
#   '11:06PM',
#   'GLOBAL MARKETS-Asian shares hit 4-month high as U.S., China recoveries gather pace'],
#  ['AMZN',
#   'Jul-02-20',
#   '11:01PM',
#   'Google, Temasek Are Said to Be in Talks to Invest in Tokopedia'],
#  ['AMZN',
#   'Jul-02-20',
#   '11:00PM',
#   'Big Techs Washington hearing will be a spectacle for the ages'],
#  ['AMZN',
#   'Jul-02-20',
#   '09:16PM',
#   'What a Democratic Sweep Could Mean for the Market'],
#  ['AMZN',
#   'Jul-02-20',
#   '07:59PM',
#   'GLOBAL MARKETS-Asian stocks set to follow U.S. jobs rally, China in focus'],
#  ['AMZN',
#   'Jul-02-20',
#   '07:51PM',
#   'Amazon Prime Day Reportedly Delayed Until October'],
#  ['AMZN',
#   'Jul-02-20',
#   '07:24PM',
#   'Google Probe Has States Split on Strategy With U.S. Antitrust\xa0Case Looming'],
#  ['AMZN',
#   'Jul-02-20',
#   '07:01PM',
#   'Amazon Stock Rose for a Ninth Straight Week. Yes, Thats a Record.'],
#  ['AMZN',
#   'Jul-02-20',
#   '06:58PM',
#   'Here Are the 10 Best-Performing Tech Stocks in the First Half. At Least 1 Has Gone Too Far.'],
#  ['AMZN', 'Jul-02-20', '04:55PM', 'Why Amazon Shares Rose 13% in June'],
#  ['AMZN',
#   'Jul-02-20',
#   '03:28PM',
#   'Bezos wealth soars over $170B, tops pre-divorce record'],
#  ['AMZN',
#   'Jul-02-20',
#   '03:20PM',
#   'Big tech CEOs will testify before Congress on antitrust inquiry: RPT'],
#  ['AMZN',
#   'Jul-02-20',
#   '01:42PM',
#   "Nifty FAANG and Other 'One Decision' Investment Strategies"],
#  ['AMZN',
#   'Jul-02-20',
#   '01:14PM',
#   'Amazon Getting a Boost From Public Sectors Shift to Cloud, Analyst Says'],
#  ['AMZN',
#   'Jul-02-20',
#   '12:55PM',
#   "REFILE-State Dept warns top U.S. firms over supply chain risks linked to China's Xinjiang"],
#  ['AMZN',
#   'Jul-02-20',
#   '12:30PM',
#   "Google's Latest Attempt to Fight Back Against Amazon"],
#  ['AMZN',
#   'Jul-02-20',
#   '12:00PM',
#   'Amazon (AMZN) Is Up 0.67% in One Week: What You Should Know'],
#  ['AMZN',
#   'Jul-02-20',
#   '11:16AM',
#   'Catch goPuff if You Can  A Vertically Integrated Consumer Tech Company Delivering Instant Needs'],
#  ['AMZN', 'Jul-02-20', '11:05AM', '3 Monster Stocks in the Making'],
#  ['AMZN',
#   'Jul-02-20',
#   '10:12AM',
#   'The Zacks Analyst Blog Highlights: Amazon.com, Snap, Netflix, PayPal and Match Group'],
#  ['AMZN',
#   'Jul-02-20',
#   '10:05AM',
#   'Tech leaders agree to testify on Capitol Hill'],
#  ['AMZN',
#   'Jul-02-20',
#   '10:00AM',
#   "Amazon's Twitch Sees Massive Surge in Engagement Amid COVID-19 Lockdowns"],
#  ['AMZN',
#   'Jul-02-20',
#   '09:32AM',
#   'What could save the stock market in July? More government borrowing and Federal Reserve money printing'],
#  ['AMZN',
#   'Jul-02-20',
#   '09:15AM',
#   "Target's Joining the Biggest Trend in E-Commerce"],
#  ['AMZN',
#   'Jul-02-20',
#   '09:00AM',
#   "Here's Why Conventional Cable's Biggest Threat Is ... Google? Yes, Google."],
#  ['AMZN', 'Jul-02-20', '08:54AM', 'Why Shopify Stock Jumped 25.3% in June'],
#  ['AMZN',
#   'Jul-02-20',
#   '08:30AM',
#   'These 5 Dividend Funds Offer the Flexibility to Weather the Pandemic'],
#  ['AMZN',
#   'Jul-02-20',
#   '08:08AM',
#   'Dow Jones Futures Signal More Gains For Coronavirus Stock Market Rally; Tesla Surges Again On Strong Deliveries'],
#  ['AMZN',
#   'Jul-02-20',
#   '07:21AM',
#   'Mark My Words: Amazon Will Hit $3 Trillion in 4 Years (or Less)'],
#  ['AMZN',
#   'Jul-02-20',
#   '07:00AM',
#   'Influencers with Andy Serwer: Scooter Braun'],
#  ['AMZN',
#   'Jul-02-20',
#   '06:49AM',
#   'Pandemic Fails to Deter YTD Rally of These Top 5 US Behemoths'],
#  ['AMZN',
#   'Jul-02-20',
#   '06:30AM',
#   '[video]AWS Is Still Very Unique in Some Important Ways'],
#  ['AMZN',
#   'Jul-02-20',
#   '06:28AM',
#   "Amazon CEO Jeff Bezos's Net Worth Tops Pre-Divorce Height: Bloomberg Index"],
#  ['AMZN',
#   'Jul-02-20',
#   '06:11AM',
#   'Amazon Borrows $10 Billion at Record Low Interest Rates'],
#  ['AMZN',
#   'Jul-02-20',
#   '06:00AM',
#   "The political 'climate on both sides is very frustrating for me': Scooter Braun"],
#  ['AMZN',
#   'Jul-02-20',
#   '06:00AM',
#   'How to Play Lululemon as It Moves Into Pelotons Space'],
#  ['AMZN',
#   'Jul-02-20',
#   '05:20AM',
#   'Sony\xa0Weighs Bid for Hong Kong-Listed\xa0Gaming Firm Leyou'],
#  ['AMZN',
#   'Jul-02-20',
#   '04:00AM',
#   'Google, Facebook Would Face FTC Over Policies in Democratic Bill'],
#  ['AMZN',
#   'Jul-02-20',
#   '12:45AM',
#   'Facebook, Amazon, Apple, Google CEOs Agree To Jointly Testify Before Congress In Antitrust Case'],
#  ['AMZN',
#   'Jul-01-20',
#   '07:28PM',
#   'US Indexes Close Mostly Higher to Start July'],
#  ['AMZN',
#   'Jul-01-20',
#   '07:20PM',
#   'The Rise of E-Commerce and Cloud Services Positions Amazon (AMZN) for the Win'],
#  ['AMZN',
#   'Jul-01-20',
#   '06:30PM',
#   'CEOs of Alphabet, Amazon, Apple and Facebook to testify before Congress in late July: report'],
#  ['AMZN',
#   'Jul-01-20',
#   '06:04PM',
#   'U.S. tech chief executives expected to testify before House panel in late July - sources'],
#  ['AMZN',
#   'Jul-01-20',
#   '05:35PM',
#   'The Dow Just Dropped 78 Points. Here Are 3 Reasons to Be Optimistic About the Market.'],
#  ['AMZN',
#   'Jul-01-20',
#   '04:59PM',
#   'Stock Market Today: Nasdaq Hits New Highs to Start Q3'],
#  ['AMZN',
#   'Jul-01-20',
#   '04:20PM',
#   'FedEx Stock Soared Today. Heres What Wall Street Is Saying.'],
#  ['AMZN', 'Jul-01-20', '04:05PM', '17 Wonderful Work-From-Home Stocks to Buy'],
#  ['AMZN',
#   'Jul-01-20',
#   '03:32PM',
#   'The work-from-home ETF is here. Get ready for some surprises.'],
#  ['AMZN', 'Jul-01-20', '03:21PM', 'Why Shares of Etsy Soared Higher in June'],
#  ['AMZN',
#   'Jul-01-20',
#   '02:33PM',
#   'Stress Test Results Could Lead to Dividend Cuts -- Should Bank Investors Worry?'],
#  ['AMZN',
#   'Jul-01-20',
#   '01:54PM',
#   "CORRECTED-NBCU's Peacock strikes deal with ViacomCBS to stream 'The Godfather' and others"],
#  ['AMZN',
#   'Jul-01-20',
#   '01:51PM',
#   "NBCUniversal's Streaming Service Peacock Will Launch With Some ViacomCBS Content"],
#  ['AMZN',
#   'Jul-01-20',
#   '12:33PM',
#   'Peloton app comes to Roku devices, stock gains'],
#  ['AMZN', 'Jul-01-20', '12:19PM', '5 Top Stocks for July'],
#  ['AMZN', 'Jul-01-20', '12:01PM', 'Streaming TV services increase prices'],
#  ['AMZN',
#   'Jul-01-20',
#   '12:00PM',
#   'DocuSign Is the Amazon of the Legal Profession'],
#  ['AMZN',
#   'Jul-01-20',
#   '11:29AM',
#   "How Much of Walmart's Online Sales Growth Came From Groceries?"],
#  ['AMZN', 'Jul-01-20', '11:15AM', "5 Stocks I'll Hold Forever"],
#  ['AMZN',
#   'Jul-01-20',
#   '11:00AM',
#   'Target Has Found Its Footing During Pandemic'],
#  ['AMZN', 'Jul-01-20', '10:57AM', 'Googles YouTube TV raises prices'],
#  ['AMZN',
#   'Jul-01-20',
#   '10:44AM',
#   'How TheSkimm Makes Money: Advertisements and Subscription Services'],
#  ['AMZN',
#   'Jul-01-20',
#   '10:38AM',
#   "Home Depot Has an Advantage Amazon Can't Take Away"],
#  ['AMZN',
#   'Jul-01-20',
#   '10:25AM',
#   'Microsoft Tried to Take on Amazon in Videogame Streaming. It Quickly Failed.'],
#  ['AMZN',
#   'Jul-01-20',
#   '10:24AM',
#   'June Stock Market Review: Spiking Coronavirus Cases Slow the Reopening Rebound'],
#  ['AMZN',
#   'Jul-01-20',
#   '09:45AM',
#   'Facebook Boycott Adds to an Already Bleak Year for Advertising'],
#  ['AMZN',
#   'Jul-01-20',
#   '09:21AM',
#   'Walmart Stock Could Book Impressive Third Quarter Gains'],
#  ['AMZN',
#   'Jul-01-20',
#   '09:21AM',
#   'ViacomCBS taps Amazon executive to replace CFO Spade'],
#  ['AMZN', 'Jul-01-20', '08:58AM', 'Why Are Business Ethics Important?'],
#  ['AMZN',
#   'Jul-01-20',
#   '08:51AM',
#   'ViacomCBS taps Amazon executive for CFO post'],
#  ['AMZN',
#   'Jul-01-20',
#   '08:46AM',
#   '5 Stocks for Millennials to Watch in the New Normal'],
#  ['AMZN',
#   'Jul-01-20',
#   '08:30AM',
#   '5 Warren Buffett Stocks You Can Buy and Hold for the Next Decade'],
#  ['AMZN',
#   'Jul-01-20',
#   '08:25AM',
#   "Amazon's Brand Value Surges 32% Higher, According to Influential Study"],
#  ['AMZN',
#   'Jul-01-20',
#   '08:22AM',
#   'Internet Indispensable to New Normal: 5 Top Picks for 2H20'],
#  ['AMZN',
#   'Jul-01-20',
#   '07:00AM',
#   'How the Coronavirus Has Widened Retailings Competitive Gap'],
#  ['TSLA',
#   'Jul-05-20',
#   '02:56PM',
#   "Dow Jones Futures: Coronavirus Stock Market Rally Fades, But Four New Breakouts; What's Next For Tesla?"],
#  ['TSLA', 'Jul-05-20', '01:00PM', 'Teslas Ambitious Plan To Ditch Cobalt'],
#  ['TSLA',
#   'Jul-05-20',
#   '12:54PM',
#   'The Auto Industry And Tesla: A Retrospective'],
#  ['TSLA',
#   'Jul-05-20',
#   '09:04AM',
#   'No Joke: Tesla Could Be Helping Make a Coronavirus Vaccine'],
#  ['TSLA', 'Jul-04-20', '07:00PM', 'How Tesla Became More Valuable Than Exxon'],
#  ['TSLA',
#   'Jul-04-20',
#   '04:25PM',
#   'Tesla To Source Additional Batteries From LG Chem'],
#  ['TSLA',
#   'Jul-04-20',
#   '02:58PM',
#   'Bulls And Bears Of The Week: Lululemon, Square, Tesla And More'],
#  ['TSLA',
#   'Jul-04-20',
#   '11:02AM',
#   'ESPAÑOL  La Caída de Aphria, Cannabis en Ecuador, Tesla Supera a Toyota, Ford y GM, y Más'],
#  ['TSLA',
#   'Jul-04-20',
#   '08:16AM',
#   'Tesla No Longer Even A Growth Company; Going Bankrupt: Shortseller'],
#  ['TSLA',
#   'Jul-04-20',
#   '07:30AM',
#   'There Are Now 4 Trillion-Dollar Stocks. Why There Might Not Be a Fifth Anytime Soon.'],
#  ['TSLA', 'Jul-03-20', '04:03PM', 'Tesla Still Amazes Nonbelievers'],
#  ['TSLA',
#   'Jul-03-20',
#   '10:09AM',
#   'Elon Musk To Bring Tesla Cybertruck On Cross-Country Drive'],
#  ['TSLA',
#   'Jul-03-20',
#   '09:51AM',
#   'The Next Wirecard? 20 Things To Watch For To Spot A Massive Market Fraud'],
#  ['TSLA',
#   'Jul-03-20',
#   '08:46AM',
#   'EV Stocks on Fire: Will Tesla Make it to the S&P 500 List?'],
#  ['TSLA',
#   'Jul-03-20',
#   '08:42AM',
#   'Tesla shareholders keen to oust Elon Musk over $55 billion bonus'],
#  ['TSLA',
#   'Jul-03-20',
#   '07:53AM',
#   'Ford Sees 33.3% Fall in Q2 Sales Volume, Partners With Disney'],
#  ['TSLA',
#   'Jul-03-20',
#   '07:16AM',
#   'Tesla Deliveries Could Top 500,000 in 2020'],
#  ['TSLA',
#   'Jul-03-20',
#   '05:45AM',
#   "Tesla's Overexcited Fans Should Cool Down a Little"],
#  ['TSLA',
#   'Jul-03-20',
#   '03:34AM',
#   'LG Chem to produce Tesla batteries in South Korea this year as demand grows - source'],
#  ['TSLA',
#   'Jul-03-20',
#   '03:30AM',
#   'LG Chem to produce Tesla batteries in South Korea this year as demand grows: source'],
#  ['TSLA',
#   'Jul-03-20',
#   '01:33AM',
#   'Nikola Founder Channels Elon Musk in Lashing Out at Naysayer Tweets'],
#  ['TSLA',
#   'Jul-03-20',
#   '12:30AM',
#   'Battery Giant TDK Expects Virus to Boost Gadget, Auto Prospects'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:49PM',
#   'Tesla denies reports of firing employees who chose to stay at home'],
#  ['TSLA',
#   'Jul-02-20',
#   '07:46PM',
#   'Tesla denies reports of firing employees who chose to stay at home'],
#  ['TSLA',
#   'Jul-02-20',
#   '07:42PM',
#   'Tesla denies reports of firing employees who chose to stay at home'],
#  ['TSLA',
#   'Jul-02-20',
#   '07:30PM',
#   'The Unemployment Rate Is Grossly Understated. Heres Why.'],
#  ['TSLA', 'Jul-02-20', '06:43PM', 'Elon Musk Trolls Short Sellers on Twitter'],
#  ['TSLA',
#   'Jul-02-20',
#   '05:41PM',
#   'Nasdaq Soars into 4th of July Weekend at Fresh All-Time Highs'],
#  ['TSLA',
#   'Jul-02-20',
#   '05:24PM',
#   'Nasdaq Hits New Records as Tesla Delivers, Keeps Soaring'],
#  ['TSLA',
#   'Jul-02-20',
#   '05:16PM',
#   'Were Hedge Funds Right About Piling Into Tesla Inc. (TSLA)?'],
#  ['TSLA',
#   'Jul-02-20',
#   '05:01PM',
#   'Elon Musk Mocks the SEC on Twitter -- Again'],
#  ['TSLA',
#   'Jul-02-20',
#   '04:37PM',
#   'Elon Musk Taunts the SEC Amid Surge in Tesla Stock Price'],
#  ['TSLA',
#   'Jul-02-20',
#   '04:33PM',
#   'Tesla stock ends at new record, tops $1,200'],
#  ['TSLA',
#   'Jul-02-20',
#   '04:29PM',
#   'CORRECTED-US STOCKS-Wall Street closes higher after biggest payrolls jump on record'],
#  ['TSLA',
#   'Jul-02-20',
#   '04:00PM',
#   'US STOCKS-Wall Street closes higher after biggest payrolls jump on record'],
#  ['TSLA',
#   'Jul-02-20',
#   '03:43PM',
#   'Tesla could hit $2,000 in best-case scenario, says analyst'],
#  ['TSLA',
#   'Jul-02-20',
#   '03:42PM',
#   'Why Tesla (TSLA) Shares Are Soaring Today (Again)'],
#  ['TSLA',
#   'Jul-02-20',
#   '03:20PM',
#   'Tesla leaps as Q2 deliveries smash forecasts'],
#  ['TSLA',
#   'Jul-02-20',
#   '02:44PM',
#   "Stock Market Today With Jim Cramer: Buy Tesla's Delivery Beat"],
#  ['TSLA',
#   'Jul-02-20',
#   '02:36PM',
#   'US STOCKS-Wall Street jumps on record payrolls surge'],
#  ['TSLA',
#   'Jul-02-20',
#   '02:33PM',
#   'Dow Jones Set For 1,000 Point Weekly Gain As Stocks Rally On Strong Jobs Report'],
#  ['TSLA',
#   'Jul-02-20',
#   '01:42PM',
#   'US STOCKS-Wall St gains as job growth accelerates, Nasdaq hits record high'],
#  ['TSLA',
#   'Jul-02-20',
#   '01:15PM',
#   "What's behind Tesla's big beat on Q2 deliveries"],
#  ['TSLA',
#   'Jul-02-20',
#   '12:56PM',
#   "Dow Jones Soars 450 Points On 'Great Jobs Numbers'; Apple Nears Record, While Tesla Surges 9% On Strong Deliveries"],
#  ['TSLA',
#   'Jul-02-20',
#   '12:55PM',
#   'Tesla Skeptic Marvels at $48 Billion Boost From One Data Point'],
#  ['TSLA',
#   'Jul-02-20',
#   '12:43PM',
#   'Strong Jobs Data Boost Stocks Even as Covid Cases Reach Record'],
#  ['TSLA',
#   'Jul-02-20',
#   '12:29PM',
#   'Tesla May Not Be Done Rallying After Big Deliveries Beat'],
#  ['TSLA', 'Jul-02-20', '12:15PM', 'Ford Is Back in the Mix'],
#  ['TSLA',
#   'Jul-02-20',
#   '12:08PM',
#   'REFILE-US STOCKS-Wall St rises on record job growth; surging virus cases cap gains'],
#  ['TSLA',
#   'Jul-02-20',
#   '11:33AM',
#   'Wedbush raises Tesla bull case to $2,000/share'],
#  ['TSLA',
#   'Jul-02-20',
#   '11:31AM',
#   'Tesla Stock Looks Like Its Joining the S&P 500. Heres How to Calculate the Impact.'],
#  ['TSLA',
#   'Jul-02-20',
#   '11:26AM',
#   "Tesla's second-quarter deliveries send shares surging"],
#  ['TSLA',
#   'Jul-02-20',
#   '11:20AM',
#   'Tesla stock rockets higher as quarterly sales crush expectations'],
#  ['TSLA',
#   'Jul-02-20',
#   '11:01AM',
#   'Tesla Deliveries Beat Estimates On Strong Model Y, Model 3 Demand'],
#  ['TSLA',
#   'Jul-02-20',
#   '10:56AM',
#   'TABLE-Top 20 vehicles sold in the United States in Q2 2020'],
#  ['TSLA', 'Jul-02-20', '10:35AM', 'Ford, Disney partner for Bronco deal'],
#  ['TSLA', 'Jul-02-20', '10:23AM', 'Unemployment Rate Decline to 11.1%'],
#  ['TSLA',
#   'Jul-02-20',
#   '10:22AM',
#   'US STOCKS-Record job growth powers Wall St, Nasdaq hits all-time high'],
#  ['TSLA',
#   'Jul-02-20',
#   '10:21AM',
#   'Jobs Numbers Surprise to Upside, Unemployment Rate 11.1%'],
#  ['TSLA', 'Jul-02-20', '10:21AM', 'Why Tesla Stock Soared Higher on Thursday'],
#  ['TSLA',
#   'Jul-02-20',
#   '10:16AM',
#   '5 Low Leverage Stocks to Buy Amid Coronavirus-Led Debacle'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:59AM',
#   'Tesla Delivery Beat Sends Shares Surging Toward Top Price Target'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:58AM',
#   'A 400-Point Rally For Dow Jones Today As Stocks Surge On June Hiring; Tesla Scores Q2 Deliveries Coup'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:51AM',
#   'Tesla Stock Could Hit $2,000 in a Best-Case Scenario'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:48AM',
#   'Tesla Price Target Is Boosted to $2,000 by Wedbush'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:43AM',
#   'Nio Vehicle Deliveries Almost Triple in June and Second Quarter'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:32AM',
#   'Dow jumps 400 points and Nasdaq hits a fresh record Thursday as jobs report for June shows 4.8 million jobs created ahead of Independence Day holiday'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:31AM',
#   'Tesla Shares Power Higher As Q2 Delivery Figures Smash Forecasts'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:10AM',
#   'Teslas Deliveries Were Incredible. The Stock Is Flying.'],
#  ['TSLA',
#   'Jul-02-20',
#   '09:04AM',
#   "Is Nikola the Next Tesla? Investors Seem to Think It's Better"],
#  ['TSLA',
#   'Jul-02-20',
#   '09:00AM',
#   'US STOCKS-Wall St set to open higher as job growth picks up pace in June'],
#  ['TSLA',
#   'Jul-02-20',
#   '08:47AM',
#   'Tesla shares soar 9% premarket on stronger-than-expected Q2 deliveries'],
#  ['TSLA',
#   'Jul-02-20',
#   '08:42AM',
#   'Theres a Trillion Dollar Investing Opportunity in Green Innovation, Bill Gross Says. Heres How.'],
#  ['TSLA',
#   'Jul-02-20',
#   '08:12AM',
#   'Tesla beats vehicle delivery estimates for second quarter'],
#  ['TSLA',
#   'Jul-02-20',
#   '08:10AM',
#   "Jobs Report, Tesla, Facebook, McDonald's - 5 Things You Must Know Thursday"],
#  ['TSLA',
#   'Jul-02-20',
#   '08:09AM',
#   'Tesla beats vehicle delivery estimates for second quarter, shares surge'],
#  ['TSLA',
#   'Jul-02-20',
#   '08:08AM',
#   'Dow Jones Futures Signal More Gains For Coronavirus Stock Market Rally; Tesla Surges Again On Strong Deliveries'],
#  ['TSLA',
#   'Jul-02-20',
#   '07:59AM',
#   'Tesla Q2 2020 Vehicle Production & Deliveries'],
#  ['TSLA',
#   'Jul-02-20',
#   '07:21AM',
#   "Tesla's Shares March Higher, Can It Continue?"],
#  ['TSLA',
#   'Jul-02-20',
#   '07:16AM',
#   'Tesla stock price target boosted to $2,000 by Wedbush, making it the highest among FactSet analysts'],
#  ['TSLA',
#   'Jul-02-20',
#   '06:49AM',
#   'Pandemic Fails to Deter YTD Rally of These Top 5 US Behemoths'],
#  ['TSLA',
#   'Jul-02-20',
#   '05:24AM',
#   'Tesla to make molecule printers for German COVID-19 vaccine developer CureVac'],
#  ['TSLA',
#   'Jul-02-20',
#   '05:21AM',
#   "Musk says Tesla is building 'RNA microfactories' for CureVac"],
#  ['TSLA',
#   'Jul-02-20',
#   '02:32AM',
#   "Tesla overtakes Toyota to become world's most valuable carmaker"],
#  ['TSLA',
#   'Jul-02-20',
#   '01:52AM',
#   'Tesla Under Federal Probe Over Fatal Battery Design Flaw'],
#  ['TSLA',
#   'Jul-01-20',
#   '08:52PM',
#   "Musk To Tesla Employees: 'Just Amazing How Well You Execute'"],
#  ['TSLA',
#   'Jul-01-20',
#   '08:19PM',
#   'Some workers complain Tesla has threatened firings if they dont return to work'],
#  ['TSLA',
#   'Jul-01-20',
#   '05:30PM',
#   'Tesla Races Ahead of Toyota to Become the Worlds Most Valuable Carmaker'],
#  ['TSLA',
#   'Jul-01-20',
#   '05:14PM',
#   'Tesla battery cooling system is subject of federal safety probe'],
#  ['TSLA',
#   'Jul-01-20',
#   '05:06PM',
#   'Forget About 2020. Next Year Is What Matters for General Motors.'],
#  ['TSLA',
#   'Jul-01-20',
#   '04:57PM',
#   'Tesla Owner Posts Video Claiming Autopilot Saved Him From Car-Deer Collision'],
#  ['TSLA',
#   'Jul-01-20',
#   '04:34PM',
#   'Its Official: Tesla Is the Most Valuable Car Company on Earth'],
#  ['TSLA',
#   'Jul-01-20',
#   '04:23PM',
#   'Tesla stock hits fresh record as Wall Street awaits Q2 sales'],
#  ['TSLA', 'Jul-01-20', '04:21PM', 'Why Tesla Stock Jumped Today'],
#  ['TSLA',
#   'Jul-01-20',
#   '04:09PM',
#   'Nasdaq notches record close to start July after Fed minutes, but Dow slumps as Boeing, Exxon shares weigh'],
#  ['TSLA',
#   'Jul-01-20',
#   '02:37PM',
#   "Tesla Surpasses Toyota To Take The Crown As World's Most Valued Automaker"],
#  ['TSLA',
#   'Jul-01-20',
#   '02:21PM',
#   'Elon Musk Stays True to His Word: Tesla Raises Full Self-Driving Price to $8,000'],
#  ['TSLA',
#   'Jul-01-20',
#   '02:20PM',
#   "Why Tesla Has Just Become the World's Most Valuable Car Company by Market Cap"],
#  ['TSLA',
#   'Jul-01-20',
#   '02:18PM',
#   'Tesla Begins Rollout Of Software Update 2020.24.6.3 In Canada'],
#  ['TSLA',
#   'Jul-01-20',
#   '01:54PM',
#   "Tesla May Be Worth More, but It's Still Not as Valuable as Toyota"],
#  ['GOOG',
#   'Jul-05-20',
#   '12:33PM',
#   'Big Tech CEOs Are Finally Ready to Talk to Congress. Heres How Theyve Handled Antirust Disclosures in the Past.'],
#  ['GOOG',
#   'Jul-05-20',
#   '07:34AM',
#   "3 Stocks to Buy in the Market That Could Mint the World's First Trillionaire"],
#  ['GOOG', 'Jul-04-20', '09:00AM', '3 Large-Cap Stocks to Buy in July'],
#  ['GOOG',
#   'Jul-03-20',
#   '11:04AM',
#   'Johnson Tells U.K. to Enjoy Summer Sensibly as Pubs Re-Open'],
#  ['GOOG',
#   'Jul-03-20',
#   '10:00AM',
#   'Google Stays in the Augmented Reality Race with a New Acquisition'],
#  ['GOOG',
#   'Jul-03-20',
#   '07:00AM',
#   'Balkanization Is Bad for Facebooks Business'],
#  ['GOOG',
#   'Jul-03-20',
#   '06:49AM',
#   'Zooms Newest Challenger: Budding Internet Tycoon Mukesh Ambani'],
#  ['GOOG',
#   'Jul-03-20',
#   '04:11AM',
#   "Google-backed groups criticize Apple's new warnings on user tracking"],
#  ['GOOG',
#   'Jul-02-20',
#   '11:01PM',
#   'Google, Temasek Are Said to Be in Talks to Invest in Tokopedia'],
#  ['GOOG',
#   'Jul-02-20',
#   '09:30PM',
#   'His Wealth Surged by $25 Billion. Then Jack Mas Rival Quit'],
#  ['GOOG',
#   'Jul-02-20',
#   '07:24PM',
#   'Google Probe Has States Split on Strategy With U.S. Antitrust\xa0Case Looming'],
#  ['GOOG',
#   'Jul-02-20',
#   '06:48PM',
#   'Why Pinterest Shot as Much as 5.5% Higher on Thursday'],
#  ['GOOG',
#   'Jul-02-20',
#   '05:52PM',
#   'Were Hedge Funds Right About Piling Into Alphabet Inc (GOOGL)?'],
#  ['GOOG',
#   'Jul-02-20',
#   '03:20PM',
#   'Big tech CEOs will testify before Congress on antitrust inquiry: RPT'],
#  ['GOOG',
#   'Jul-02-20',
#   '01:16PM',
#   'Facebook, Google, EBay: Tech Stock Midday Movers'],
#  ['GOOG',
#   'Jul-02-20',
#   '01:10PM',
#   'CEOs of Facebook, Amazon, Apple and Google to Testify at House Antitrust Hearing'],
#  ['GOOG',
#   'Jul-02-20',
#   '12:54PM',
#   'Facebook Accused by Black Manager of Systemic Discrimination'],
#  ['GOOG',
#   'Jul-02-20',
#   '12:48PM',
#   "EU regulators checking if Fitbit deal will boost Google's clout"],
#  ['GOOG',
#   'Jul-02-20',
#   '12:41PM',
#   'U.S. Senate committee approves anti-child porn bill after addressing Google, Facebook encryption concerns'],
#  ['GOOG',
#   'Jul-02-20',
#   '12:30PM',
#   "Google's Latest Attempt to Fight Back Against Amazon"],
#  ['GOOG',
#   'Jul-02-20',
#   '11:16AM',
#   "Groups warn against Google's purchase of Fitbit"],
#  ['GOOG',
#   'Jul-02-20',
#   '10:19AM',
#   'If You Own Alphabet (GOOG) Stock, Should You Sell It Now?'],
#  ['GOOG',
#   'Jul-02-20',
#   '10:05AM',
#   'Tech leaders agree to testify on Capitol Hill'],
#  ['GOOG',
#   'Jul-02-20',
#   '10:00AM',
#   "Amazon's Twitch Sees Massive Surge in Engagement Amid COVID-19 Lockdowns"],
#  ['GOOG',
#   'Jul-02-20',
#   '09:32AM',
#   'What could save the stock market in July? More government borrowing and Federal Reserve money printing'],
#  ['GOOG',
#   'Jul-02-20',
#   '09:20AM',
#   'Do You Really Want Google to Have Your Personal Fitness Data?'],
#  ['GOOG', 'Jul-02-20', '09:00AM', 'Overpaying for TV Again? Get Used to It.'],
#  ['GOOG',
#   'Jul-02-20',
#   '09:00AM',
#   "Here's Why Conventional Cable's Biggest Threat Is ... Google? Yes, Google."],
#  ['GOOG',
#   'Jul-02-20',
#   '08:08AM',
#   'Dow Jones Futures Signal More Gains For Coronavirus Stock Market Rally; Tesla Surges Again On Strong Deliveries'],
#  ['GOOG',
#   'Jul-02-20',
#   '06:30AM',
#   '[video]AWS Is Still Very Unique in Some Important Ways'],
#  ['GOOG',
#   'Jul-02-20',
#   '06:00AM',
#   "The political 'climate on both sides is very frustrating for me': Scooter Braun"],
#  ['GOOG',
#   'Jul-02-20',
#   '04:00AM',
#   'Google, Facebook Would Face FTC Over Policies in Democratic Bill'],
#  ['GOOG',
#   'Jul-02-20',
#   '01:00AM',
#   'Behind the Lens: How Googles Street View Traveler Is Capturing the Worlds Most Iconic Places'],
#  ['GOOG',
#   'Jul-02-20',
#   '12:45AM',
#   'Facebook, Amazon, Apple, Google CEOs Agree To Jointly Testify Before Congress In Antitrust Case'],
#  ['GOOG',
#   'Jul-02-20',
#   '12:30AM',
#   'Google, Gap Inc. Discuss Navigating the Path Forward'],
#  ['GOOG',
#   'Jul-01-20',
#   '11:05PM',
#   "U.S., EU advocacy groups warn against Google's purchase of Fitbit"],
#  ['GOOG',
#   'Jul-01-20',
#   '11:00PM',
#   'EU signals deeper investigation of Google Fitbit deal'],
#  ['GOOG',
#   'Jul-01-20',
#   '10:17PM',
#   "U.K. regulators take aim at Apple's search engine deal with Google"],
#  ['GOOG',
#   'Jul-01-20',
#   '08:36PM',
#   'China Upstart CEO Steps Down After Building $44 Billion Fortune'],
#  ['GOOG',
#   'Jul-01-20',
#   '07:31PM',
#   'Apple, Facebook, Amazon and Google CEOs to Testify to Congress: Report'],
#  ['GOOG',
#   'Jul-01-20',
#   '06:30PM',
#   'CEOs of Alphabet, Amazon, Apple and Facebook to testify before Congress in late July: report'],
#  ['GOOG',
#   'Jul-01-20',
#   '06:12PM',
#   'U.S. tech chief executives expected to testify before House panel in late July'],
#  ['GOOG', 'Jul-01-20', '06:03PM', 'Seth Klarman Ups Stake in Translate Bio'],
#  ['GOOG',
#   'Jul-01-20',
#   '03:26PM',
#   'U.S. senator to change anti-child porn bill over Google, Facebook encryption concerns: draft'],
#  ['GOOG',
#   'Jul-01-20',
#   '02:53PM',
#   "UK regulators take aim at Apple's search engine deal with Google"],
#  ['GOOG',
#   'Jul-01-20',
#   '01:10PM',
#   'Arizona Has Record Case Increase; Vaccine Promise: Virus Update'],
#  ['GOOG',
#   'Jul-01-20',
#   '12:45PM',
#   'Virtual MVPDs Are Suffering the Same Fate as Traditional Cable'],
#  ['GOOG',
#   'Jul-01-20',
#   '12:33PM',
#   'Peloton app comes to Roku devices, stock gains'],
#  ['GOOG',
#   'Jul-01-20',
#   '12:23PM',
#   'Google and Facebook too powerful, says watchdog'],
#  ['GOOG', 'Jul-01-20', '12:01PM', 'Streaming TV services increase prices'],
#  ['GOOG',
#   'Jul-01-20',
#   '11:40AM',
#   'Constellation Brands buys direct-to-consumer Empathy Wines'],
#  ['GOOG', 'Jul-01-20', '10:57AM', 'Googles YouTube TV raises prices'],
#  ['GOOG',
#   'Jul-01-20',
#   '10:44AM',
#   'How TheSkimm Makes Money: Advertisements and Subscription Services'],
#  ['GOOG',
#   'Jul-01-20',
#   '09:45AM',
#   'Facebook Boycott Adds to an Already Bleak Year for Advertising'],
#  ['GOOG',
#   'Jul-01-20',
#   '09:38AM',
#   'EU throws new rule book at Google, tech giants in competition search'],
#  ['GOOG',
#   'Jul-01-20',
#   '09:26AM',
#   'EU throws new rule book at Google, tech giants in competition search'],
#  ['GOOG',
#   'Jul-01-20',
#   '09:01AM',
#   'Google Puts Off Reopening Offices As Coronavirus Infections Escalate'],
#  ['GOOG', 'Jul-01-20', '08:58AM', 'Why Are Business Ethics Important?'],
#  ['GOOG', 'Jul-01-20', '07:59AM', 'Lyft Resumes Self-Driving Test Rides'],
#  ['GOOG',
#   'Jul-01-20',
#   '07:27AM',
#   'UK body wants tougher checks for Google, Facebook ad reign'],
#  ['GOOG',
#   'Jun-30-20',
#   '11:57PM',
#   'Google postpones U.S. office reopening to September as virus cases spike'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:51PM',
#   'Google Pushes Back U.S. Office Reopening Plan After Virus Surge'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:24PM',
#   'UK competition watchdog ignores calls for online ad sector probe'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:09PM',
#   'India TikTok Ban Threatens Chinas Rise as Global Tech Power'],
#  ['GOOG',
#   'Jun-30-20',
#   '08:26PM',
#   'Alphabet Raises Monthly YouTubeTV Price by 30% to $64.99'],
#  ['GOOG',
#   'Jun-30-20',
#   '05:54PM',
#   'YouTube TV Hikes Price 30% to $65 Per Month, Blames Content Costs'],
#  ['GOOG',
#   'Jun-30-20',
#   '05:45PM',
#   'Alphabet (GOOGL) Gains But Lags Market: What You Should Know'],
#  ['GOOG',
#   'Jun-30-20',
#   '04:24PM',
#   'YouTube TV price hike underscores power of Netflix, analyst says'],
#  ['GOOG',
#   'Jun-30-20',
#   '03:17PM',
#   'YouTube TV Boosts Its Price by 30%. Its Starting to Look a Lot Like Cable.'],
#  ['GOOG',
#   'Jun-30-20',
#   '03:04PM',
#   "Alphabet's YouTube Could Benefit from Facebook Ad Boycott: Analyst"],
#  ['GOOG', 'Jun-30-20', '02:49PM', 'Why Himax Technologies Stock Soared Today'],
#  ['GOOG', 'Jun-30-20', '02:32PM', 'Google hikes YouTube TV price to $64.99'],
#  ['GOOG',
#   'Jun-30-20',
#   '01:58PM',
#   'Google Buys Startup North to Support Ambient Computing Quest'],
#  ['GOOG',
#   'Jun-30-20',
#   '01:56PM',
#   'Google Snaps Up Canadian Smart Glasses Startup North'],
#  ['GOOG', 'Jun-30-20', '12:30PM', 'The Robots Will Handle Your Finances Now'],
#  ['GOOG',
#   'Jun-30-20',
#   '12:01PM',
#   'Facebook Tweaks News Ranking, Prioritizes Original Material'],
#  ['GOOG',
#   'Jun-30-20',
#   '11:50AM',
#   'Google says it has acquired smart glasses maker North'],
#  ['GOOG',
#   'Jun-30-20',
#   '11:31AM',
#   'Thousands Stranded, Families Separated After Trump H-1B Decree'],
#  ['GOOG',
#   'Jun-30-20',
#   '10:43AM',
#   'Amazon Cloud Group Targets Space, Government Deals With New Unit'],
#  ['GOOG',
#   'Jun-30-20',
#   '10:40AM',
#   'Can the Tech Giants Successfully Copy TikTok?'],
#  ['GOOG',
#   'Jun-30-20',
#   '10:34AM',
#   'Microsoft vs Alphabet: You Wont Believe This!'],
#  ['GOOG',
#   'Jun-30-20',
#   '10:05AM',
#   'Apple (AAPL) News Services Loses The New York Times Content'],
#  ['GOOG',
#   'Jun-30-20',
#   '10:00AM',
#   'Covid-19 Shows That Scientific Journals Need to Open Up'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:55AM',
#   'Major indices open flat as coronavirus cases climb'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:49AM',
#   'Google Curbs Fake Info by Removing Misleading Voting Ads'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:47AM',
#   "Amazon's Brand Value Crosses $400 Billion Amid Lockdowns"],
#  ['GOOG',
#   'Jun-30-20',
#   '09:39AM',
#   'Rare coins, whiskey and even Lego  some of the niche investments being considered during the pandemic'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:16AM',
#   '#StopHateforProfit Strains Ad Revenues: 3 Stocks at Risk'],
#  ['GOOG',
#   'Jun-30-20',
#   '09:00AM',
#   'IEIC Welcomes Netskope as a Founding Member'],
#  ['GOOG',
#   'Jun-30-20',
#   '08:44AM',
#   'Watch these two important levels in the stock market to see which way prices may go'],
#  ['GOOG',
#   'Jun-30-20',
#   '04:12AM',
#   'Google stymies media companies from chipping away at its data dominance'],
#  ['GOOG',
#   'Jun-30-20',
#   '12:00AM',
#   'Trump Visa Freeze Endangers India Tech Industrys Talent Model'],
#  ['GOOG',
#   'Jun-29-20',
#   '09:05PM',
#   'India Bans 59 Apps, Including TikTok and WeChat, Citing Security'],
#  ['GOOG',
#   'Jun-29-20',
#   '08:10PM',
#   'Google takes down misleading ads related to voting, elections'],
#  ['GOOG',
#   'Jun-29-20',
#   '08:05PM',
#   "Google removes ads served to users seeking voting info for 'misrepresentation'"],
#  ['GOOG',
#   'Jun-29-20',
#   '05:20PM',
#   'YouTube Bans More White Supremacist Channels for Hate Speech'],
#  ['GOOG',
#   'Jun-29-20',
#   '05:00PM',
#   'Chinese Smartphone Giant Vivo Is Latest to Splurge on Tech Tower'],
#  ['GOOG',
#   'Jun-29-20',
#   '04:53PM',
#   'Microsoft Pauses Facebook, Instagram Advertising Spending'],
#  ['GOOG',
#   'Jun-29-20',
#   '04:50PM',
#   'The Nasdaq isnt just beating the Dow and S&P 500, its having one of its best first halves ever against its stock-market peers'],
#  ['GOOG',
#   'Jun-29-20',
#   '03:47PM',
#   "It's Zuckerberg and Facebook's Time to Bend"]]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  \
# 0   AMZN  2020-07-05  12:35PM
# 1   AMZN  2020-07-05  12:34PM
# 2   AMZN  2020-07-05  12:33PM
# 3   AMZN  2020-07-05  11:29AM
# 4   AMZN  2020-07-05  11:11AM
#
#                                             headline    neg    neu    pos  \
# 0       Another AT&T Streaming Service May Be Doomed  0.412  0.588  0.000
# 1                                  NASDAQ vs The DOW  0.000  1.000  0.000
# 2  Big Tech CEOs Are Finally Ready to Talk to Con...  0.000  0.878  0.122
# 3  ViacomCBS Decides to License Content to Rival ...  0.000  1.000  0.000
# 4     3 Top Stocks to Recession-Proof Your Portfolio  0.000  0.735  0.265
#
#    compound
# 0   -0.6369
# 1    0.0000
# 2    0.3612
# 3    0.0000
# 4    0.2023

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()
